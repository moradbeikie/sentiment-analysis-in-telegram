# %%
import numpy as np
import pandas as pd
colNames = ["message", "messageHash", "messageClean", "length", "sentiment1", "sentiment2","chatID", "channelName", "channelMembers", "fromID", "replyToID", "mediaHash","date", "flags"]
dataset = pd.read_csv("dataset.csv", names=colNames,delimiter=',',header=None)
dataset
# Out:
#                                                  message  \
# 0      تار طرب گسسته شد، ⏎ پای طلب شکسته شد ⏎ ⏎ راه ا...
# 1      💢نامه رهبرمعظم انقلاب به احمدی‌نژاد ⏎ ⏎ ⏎ ادعا...
# 2      پر از فیلم سکسی ⏎ گیف سکسی ⏎ کیرت شق کرده بیا ...
# 3      سلام ⏎ جمعه مبارک ⏎ جمعه تون مثل لبخند زیبا ⏎ ...
# 4      نرگس ار لاف زد از شیوه چشم تو مرنج ⏎ نروند اهل...
# ...                                                  ...
# 85736   نوشته شعر فقط بهانه است، من با صدای بلند به ش...
# 85737                سیستمت اگه 10 باشه 10player هم میشه
# 85738  سلام دوتا سوال از سینتیک و طراحی راکتور دارم ک...
# 85739   یه مرکز خیریه هست به اسم موسسه رضوان ادرس موس...
# 85740  سلام ⏎ از همکاران گرامی اگر کسی سرکار خانم نظر...
#
#                                              messageHash  \
# 0      18337fafa18c3c5e962526e4ac49a7a279c92cbf41c44d...
# 1      3c5efa52ad78794feda87516fcd01b6dc40b120fa831d5...
# 2      5a06451d666e1001920c0d0cb18c2cd15ed6233ad7da10...
# 3      e6c24c24054c0d31f09ef10804be3f9ed6f7b7909b658b...
# 4      8f4536e7ab814b09a3ff4c994f630ce803d792a3378adf...
# ...                                                  ...
# 85736  8b608d978e7c453e216ae3e271491cf3ce5a5162a73242...
# 85737  8f0e206e9746c8bded7819e3a236035de553aec555e931...
# 85738  545b5c87f1869a7885193bfa5865fcd64608dd4ea6e4fa...
# 85739  430a6b2c6d4dbc0de66c9db537044644ba93789f25eb9d...
# 85740  20c0da825976a840129ac71a4a41611b67d26a629acef6...
#
#                                             messageClean  length sentiment1  \
# 0      تار طرب گسسته  ⏎ پای طلب شکسته ⏎ ⏎ راه امید بس...     221   negative
# 1      💢نامه رهبرمعظم انقلاب احمدی نژاد ⏎ ⏎ ⏎ ادعای غ...     206   negative
# 2      پر فیلم سکسی ⏎ گیف سکسی ⏎ کیرت شق کرده توووو ⏎...     205   negative
# 3      سلام ⏎ جمعه مبارک ⏎ جمعه تون مثل لبخند زیبا ⏎ ...     161   negative
# 4      نرگس ار لاف زد شیوه چشم مرنج ⏎ نروند اهل نظر پ...     163   negative
# ...                                                  ...     ...        ...
# 85736           نوشته شعر فقط بهانه  صدای بلند فکر میکنم      57   negative
# 85737                   سیستمت اگه 10 باشه 10player میشه      35   negative
# 85738  سلام دوتا سوال سینتیک طراحی راکتور دارم کسی بلده؟      54   positive
# 85739   یه مرکز خیریه هست اسم موسسه رضوان ادرس موسسه ...     107   negative
# 85740  سلام ⏎ همکاران گرامی اگر کسی سرکار خانم نظری م...     104   negative
#
#       sentiment2      chatID  \
# 0            NaN  1101714024
# 1            NaN  1058951347
# 2            NaN  1074131680
# 3            NaN  1139514870
# 4            NaN  1136838204
# ...          ...         ...
# 85736        NaN  1064887036
# 85737        NaN  1061272637
# 85738        NaN  1149441708
# 85739        NaN  1070380010
# 85740        NaN  1108364493
#
#                                              channelName  channelMembers  \
# 0                               انــیــمــ şђąß ġąяĐیــت               0
# 1                                   🍃🌷بیــت الشـ❤ــهدا🌷🍃               0
# 2                                             Jet Link 6               0
# 3                               ☕️🌿نيوشا راز ِسلامتي 🌿☕️               0
# 4                                                  دلکده               0
# ...                                                  ...             ...
# 85736                                 آلمان تحصیل، پرگار               0
# 85737                                               BUG🐞               0
# 85738                                  کنکور مهندسی شیمی               0
# 85739                          ((دیواربزرگ بردسیروحومه))               0
# 85740  کارگروه علوم انسانی انجمن اساتید حق‌التدریس اس...               0
#
#           fromID          replyToID mediaHash                      date  flags
# 0       57975330                  0     photo  2018-02-23T07:30:04.000Z      0
# 1      373767048                  0     photo  2018-02-23T07:29:40.000Z      0
# 2      548787448                  0     photo  2018-02-23T07:32:06.000Z      0
# 3      253117966                  0     photo  2018-02-23T07:30:04.000Z      0
# 4      166682910                  0     photo  2018-02-23T07:29:15.000Z      0
# ...          ...                ...       ...                       ...    ...
# 85736   55487707  1064887036_145759       NaN  2017-12-27T05:59:50.000Z      0
# 85737  241319713   1061272637_92781       NaN  2017-12-27T20:59:37.000Z      0
# 85738  122764860                  0       NaN  2017-12-26T08:08:20.000Z      0
# 85739  433036331  1070380010_214243       NaN  2017-12-27T18:27:53.000Z      0
# 85740  174693982                  0       NaN  2017-12-20T18:36:02.000Z      0
#
# [85741 rows x 14 columns]

# %%
dataset.drop('messageHash', axis=1,inplace=True)
dataset.drop('messageClean', axis=1,inplace=True)
dataset.drop('length', axis=1,inplace=True)
dataset.drop('sentiment2', axis=1,inplace=True)
dataset.drop('chatID', axis=1,inplace=True)
dataset.drop('channelName', axis=1,inplace=True)
dataset.drop('channelMembers', axis=1,inplace=True)
dataset.drop('fromID', axis=1,inplace=True)
dataset.drop('replyToID', axis=1,inplace=True)
dataset.drop('mediaHash', axis=1,inplace=True)
dataset.drop('date', axis=1,inplace=True)
dataset.drop('flags', axis=1,inplace=True)
dataset.head(2)
# Out:
#                                              message sentiment1
# 0  تار طرب گسسته شد، ⏎ پای طلب شکسته شد ⏎ ⏎ راه ا...   negative
# 1  💢نامه رهبرمعظم انقلاب به احمدی‌نژاد ⏎ ⏎ ⏎ ادعا...   negative

# %%
dataset['message']
# Out:
# 0        تار طرب گسسته شد، ⏎ پای طلب شکسته شد ⏎ ⏎ راه ا...
# 1        💢نامه رهبرمعظم انقلاب به احمدی‌نژاد ⏎ ⏎ ⏎ ادعا...
# 2        پر از فیلم سکسی ⏎ گیف سکسی ⏎ کیرت شق کرده بیا ...
# 3        سلام ⏎ جمعه مبارک ⏎ جمعه تون مثل لبخند زیبا ⏎ ...
# 4        نرگس ار لاف زد از شیوه چشم تو مرنج ⏎ نروند اهل...
#                                ...
# 85736     نوشته شعر فقط بهانه است، من با صدای بلند به ش...
# 85737                  سیستمت اگه 10 باشه 10player هم میشه
# 85738    سلام دوتا سوال از سینتیک و طراحی راکتور دارم ک...
# 85739     یه مرکز خیریه هست به اسم موسسه رضوان ادرس موس...
# 85740    سلام ⏎ از همکاران گرامی اگر کسی سرکار خانم نظر...
# Name: message, Length: 85741, dtype: object

# %%
import re

# %%
def remove_link(row):
    row = str(row)
    cleantext = re.sub(r"(?:\@|https?\://)\S+", "", row)#Links and mentions
    return cleantext.strip()

# %%
dataset['message']=dataset['message'].apply(remove_link)

# %%
dataset['message']
# Out:
# 0        تار طرب گسسته شد، ⏎ پای طلب شکسته شد ⏎ ⏎ راه ا...
# 1        💢نامه رهبرمعظم انقلاب به احمدی‌نژاد ⏎ ⏎ ⏎ ادعا...
# 2        پر از فیلم سکسی ⏎ گیف سکسی ⏎ کیرت شق کرده بیا ...
# 3        سلام ⏎ جمعه مبارک ⏎ جمعه تون مثل لبخند زیبا ⏎ ...
# 4        نرگس ار لاف زد از شیوه چشم تو مرنج ⏎ نروند اهل...
#                                ...
# 85736    نوشته شعر فقط بهانه است، من با صدای بلند به شم...
# 85737                  سیستمت اگه 10 باشه 10player هم میشه
# 85738    سلام دوتا سوال از سینتیک و طراحی راکتور دارم ک...
# 85739    یه مرکز خیریه هست به اسم موسسه رضوان ادرس موسس...
# 85740    سلام ⏎ از همکاران گرامی اگر کسی سرکار خانم نظر...
# Name: message, Length: 85741, dtype: object

# %%
dataset.message[73639]
# Out:
# 'منزل اجاره ای میخام برای زوج جوان .تازه عروس داماد. ⏎ ⏎ تازه ساز یا حداقل تمیز ⏎ کرایه تا 300-400 ⏎ پیش دو یا سه میلیون ⏎ .کسی سراغ داشت پی وی ⏎ 🙆'

# %%
dataset['message']
# Out:
# 0        تار طرب گسسته شد، ⏎ پای طلب شکسته شد ⏎ ⏎ راه ا...
# 1        💢نامه رهبرمعظم انقلاب به احمدی‌نژاد ⏎ ⏎ ⏎ ادعا...
# 2        پر از فیلم سکسی ⏎ گیف سکسی ⏎ کیرت شق کرده بیا ...
# 3        سلام ⏎ جمعه مبارک ⏎ جمعه تون مثل لبخند زیبا ⏎ ...
# 4        نرگس ار لاف زد از شیوه چشم تو مرنج ⏎ نروند اهل...
#                                ...
# 85736    نوشته شعر فقط بهانه است، من با صدای بلند به شم...
# 85737                  سیستمت اگه 10 باشه 10player هم میشه
# 85738    سلام دوتا سوال از سینتیک و طراحی راکتور دارم ک...
# 85739    یه مرکز خیریه هست به اسم موسسه رضوان ادرس موسس...
# 85740    سلام ⏎ از همکاران گرامی اگر کسی سرکار خانم نظر...
# Name: message, Length: 85741, dtype: object

# %%
dataset.message[21]
# Out:
# '🚨سلام ♪♫•*¨*•.¸¸❤ݦهدی «عڄ» ݦی آید ❤¸¸.•*¨*•♫♪ 🚨 ⏎  ⏎ 🚨بـه گروه جهانی فداییان ولايت گروه شخصیتها وبصیرت خوش آمدیداین گروه زیرنظر ربات است #قوانینی را که مدیریت گروه ذکرکرده اندرا بخوانید ازارسال #لینک ویا #تبلیغات وارسال عکس مستهجن خودداری کنیددرغیر ⏎ ایـنصـورت IP حساب کاربری شمابصورت خودکار مسدودخواهدشد🚨'

# %%
def remove_hashtag(row):
    row = str(row)
    text = re.sub(r"#\w+", "", row)
    return text

# %%
dataset['message']=dataset['message'].apply(remove_hashtag)

# %%
dataset['message']
# Out:
# 0        تار طرب گسسته شد، ⏎ پای طلب شکسته شد ⏎ ⏎ راه ا...
# 1        💢نامه رهبرمعظم انقلاب به احمدی‌نژاد ⏎ ⏎ ⏎ ادعا...
# 2        پر از فیلم سکسی ⏎ گیف سکسی ⏎ کیرت شق کرده بیا ...
# 3        سلام ⏎ جمعه مبارک ⏎ جمعه تون مثل لبخند زیبا ⏎ ...
# 4        نرگس ار لاف زد از شیوه چشم تو مرنج ⏎ نروند اهل...
#                                ...
# 85736    نوشته شعر فقط بهانه است، من با صدای بلند به شم...
# 85737                  سیستمت اگه 10 باشه 10player هم میشه
# 85738    سلام دوتا سوال از سینتیک و طراحی راکتور دارم ک...
# 85739    یه مرکز خیریه هست به اسم موسسه رضوان ادرس موسس...
# 85740    سلام ⏎ از همکاران گرامی اگر کسی سرکار خانم نظر...
# Name: message, Length: 85741, dtype: object

# %%
dataset.message[203]
# Out:
# ' ⏎  ⏎  ⏎ ⏎ ⏎ تزیین کیک پف پفیییییییی دخترونه 😍😍 ⏎ ⏎ ایده های بیشتر در کانال دیزاین کیک و شیرینی ⏎ 👇🏾👇🏾 ⏎ ⏎'

# %%
def remove_enk(row):
    row = str(row)
    cleantext = re.sub(r"[/]|[A-Z]|[a-z]|[0-9]|[۰-۹]+", "", row)
    return cleantext

# %%
dataset['message']=dataset['message'].apply(remove_enk)

# %%
dataset
# Out:
#                                                  message sentiment1
# 0      تار طرب گسسته شد، ⏎ پای طلب شکسته شد ⏎ ⏎ راه ا...   negative
# 1      💢نامه رهبرمعظم انقلاب به احمدی‌نژاد ⏎ ⏎ ⏎ ادعا...   negative
# 2      پر از فیلم سکسی ⏎ گیف سکسی ⏎ کیرت شق کرده بیا ...   negative
# 3      سلام ⏎ جمعه مبارک ⏎ جمعه تون مثل لبخند زیبا ⏎ ...   negative
# 4      نرگس ار لاف زد از شیوه چشم تو مرنج ⏎ نروند اهل...   negative
# ...                                                  ...        ...
# 85736  نوشته شعر فقط بهانه است، من با صدای بلند به شم...   negative
# 85737                          سیستمت اگه  باشه  هم میشه   negative
# 85738  سلام دوتا سوال از سینتیک و طراحی راکتور دارم ک...   positive
# 85739  یه مرکز خیریه هست به اسم موسسه رضوان ادرس موسس...   negative
# 85740  سلام ⏎ از همکاران گرامی اگر کسی سرکار خانم نظر...   negative
#
# [85741 rows x 2 columns]

# %%
dataset.to_csv('newdata.csv')

# %%
def remove(row):
    row = str(row)
    new = re.sub(r"[.():-;\'<>؛⇦◦◉|♝⚀▇╚₪₪╝#ՊՕխმՊՊმძ◠‿◠▆🔼║║╱☏★◥████◣∩│⌘↯$%&இੳஇइई┏┓♠☺☺➌♣╔╗▁▂▃▄▅▇▇▅▄▃▂▁+❢-\〰♂√™➯❅❅⛛♡✿×♀✾‌➖●●♦┄┅┅┄،!^+=:'" "@%$,«»◈◾♚※☑♥¨*♫♪⇛──═ঊঈঊঈ═──•⏎[\]]+", " ", row)#delete emoji
    return new.strip()

# %%
dataset['message']=dataset['message'].apply(remove)

# %%
def remove_emoji(row):
    row = str(row)
    new = re.sub(r"[.():-;\👙⛈⛅◘◘■ⓜⓐⓚⓐⓝⓑⓐⓝⓓ🕉🖍🛃🦍'ျ╄ြ₪🗃🖌🖍😺۩๑▬🦉🥞🦃🥨🗳Π∞🤭◔͜͡🗯🖋<>🤰🙉♌؛🕸⚛⇦🕑◦◉🚲🚊🥗🤮🚒🤧|♝🛶🛳🔢🙆⚀▇🖖♋🔠🗂╚₪₪╝😟#ՊՕխმՊՊმძ🤫◠‿◠▆↩🔼║║╱↖🔯⛪☏★😛☛🙆☜◥████◣∩│☠⌘🥒🥘↯$%&🤚☃🚧⏹🔩🔧🛂🤬😴🤵🥂😙♜இੳஇ🙅🤨┗━↗━┛😥🗒🧐🔲😽♍🧀🚶⚒🗡🤲🚖इई⌚┏┓🍑🚥🚂🚞🙇🚻🚍🖐🤝🛣🤡😮♠☸🗺🌵🕴☺☺🤪👋🕵😽➌♣💡🕺🚴🏵🤙🚷♓╔╗🗽🌰⛹🕌☕🚌🛠🕯✖🤕✴╭☃╮📎🦄🏡🌊▁▂▃▄▅▇▇▅▄▃▂▁🥝🍩╰☃╯🤐⬆👡+📹🤷💿👛👜🛡❢🗞🐟🐠📄⏪↪✒📰🤓♈🔳⛷-\🔛🏅🔓🖊😵〰🍒🤒🙋😧💬🚑⏱⛺🤦〽🔝🥔☕💪🥚🍄🥖🍄🥛🌽🍄🆑♂☕◀🕊😫🧡🐎🤼🤦🎧🌎☟⚕🕖🤦🤦🚔❓🈴🚀💶√™🙁🌧➯🍈😶🌞🔅🍹🔑💓🍢🤞🐤🤐🎩🎮🤢⛑💘🦁🔫🤑⏬☹🏁⚽🌙⛱💍👧😡🐧🔚❅❅🔖😣🔫😩🍇🤞💟😇🎛🍯📙🎄🎵🎶👫🔺🙀👅☀🍕🎤🕛🥁🤹🙌⚔🗼⛏😖⏸▓🥤😠🖕🖕😞🆕⚔⚕🚔☪⛛😓🍳😚🦅🍁🍎🌼😅⏬🍒😗👒😲👟☂🛒🏩♡🚹📖➖⬆🕗😯👎📪👒🍫👟🔖⛄⤴📊✿👠🎄🔎🏃‍♀🦋💳💲🥕📆🤤📥💉💊🏃🕳🥕🏥📦⏳✾‌🙃🔸🔓🌗➖🍅🌱🆚👋◼🏬🏢💒⚖🏛😌⚓🚩👋🍀🔸🚛🚕🕹🔸🌲🍮👿🖥📮😃🔮🚗🎈👊✊🎓🎂🐝🎞🔊😹🏽🅾💌🥉🛍🏻⚫📽⚽🏀🏈⚾🎾🥇👑😅🙊🏷⭐😼🥈👫👅🔆🌻😨📯🎨😀🚸📱🔶●⛓🌴🏆😇🤘☘🍁👦🧑👦🍷🙄💣🎭🏫✂📢😇🚘🔟📿☘👩👦🌾⭐●❣🌿☄🦂👥🌍🚺🤣🚚🌑🎋🚙🍂👻🕋🤗🚜🖼🎹👤➕😇📡🤖🎖🏻🔗🔰💧🎙↘⁉👚🌼♛📚🍊💻📲🌈⚙🤩♻⚡♦┄┅┅┄😉،!^+=:🌀🎵❣📅🎼🔹📩'" "✔🔷😷💟🗓📣📝@🔈🍏🔻📚🦇🎵🐺🔻%$☔💼⏰💸🚦💇🚪🗝🙂☯📌💀📳,🥀🌐➡🏕🏞👨👩🎶🗨🦋😕🏿«»✳Ⓜ👁⛔◈🔘◾🐴🎬😪👌♚❇😏💔👯🔜⬇※☑💎🛫♥✨👗👖🎉🎊🍌💵😱¨*♫♪📛🍆⇛♨✌⬛🔱🏴🎀🔪🤠💜💙🖤💗💛💝🎥🚬🎯☞──═ঊঈঊঈ═──😔•❗🛑▶🤠✅☎🤔↙❥😐🤔💄💞👉🎗👸😘💅😰💥💃😆🖇😈📍😋⭕🏾📷💕❌💯💖😻💚📞❄👍🕰🗣😊✈🚆📺🏼🚨🍟🍿🌳😳😒😝😁💋😄🙈🆔📸⚠🐳💐⚪️✍🌟🍃💫🔞🌷😑✋😎😬🎁⬅💠🌹👏😜👇😂🌸⚜🔴❤🙏😢👈☝😭👀🔵🌺💰🚫🔥😦😍👆💢💦⏎[\]]+", "", row)#delete emoji
    return new.strip()

# %%
dataset['message']=dataset['message'].apply(remove_emoji)

# %%
dataset
# Out:
#                                                  message sentiment1
# 0      تار طرب گسسته شد    پای طلب شکسته شد     راه ا...   negative
# 1      نامه رهبرمعظم انقلاب به احمدی نژاد       ادعای...   negative
# 2      پر از فیلم سکسی   گیف سکسی   کیرت شق کرده بیا ...   negative
# 3      سلام   جمعه مبارک   جمعه تون مثل لبخند زیبا   ...   negative
# 4      نرگس ار لاف زد از شیوه چشم تو مرنج   نروند اهل...   negative
# ...                                                  ...        ...
# 85736  نوشته شعر فقط بهانه است  من با صدای بلند به شم...   negative
# 85737                          سیستمت اگه  باشه  هم میشه   negative
# 85738  سلام دوتا سوال از سینتیک و طراحی راکتور دارم ک...   positive
# 85739  یه مرکز خیریه هست به اسم موسسه رضوان ادرس موسس...   negative
# 85740  سلام   از همکاران گرامی اگر کسی سرکار خانم نظر...   negative
#
# [85741 rows x 2 columns]

# %%
dataset
# Out:
#                                                  message sentiment1
# 0      تار طرب گسسته شد    پای طلب شکسته شد     راه ا...   negative
# 1      نامه رهبرمعظم انقلاب به احمدی نژاد       ادعای...   negative
# 2      پر از فیلم سکسی   گیف سکسی   کیرت شق کرده بیا ...   negative
# 3      سلام   جمعه مبارک   جمعه تون مثل لبخند زیبا   ...   negative
# 4      نرگس ار لاف زد از شیوه چشم تو مرنج   نروند اهل...   negative
# ...                                                  ...        ...
# 85736  نوشته شعر فقط بهانه است  من با صدای بلند به شم...   negative
# 85737                          سیستمت اگه  باشه  هم میشه   negative
# 85738  سلام دوتا سوال از سینتیک و طراحی راکتور دارم ک...   positive
# 85739  یه مرکز خیریه هست به اسم موسسه رضوان ادرس موسس...   negative
# 85740  سلام   از همکاران گرامی اگر کسی سرکار خانم نظر...   negative
#
# [85741 rows x 2 columns]

# %%
dataset.shape
# Out:
# (85741, 2)

# %%
dataset.message[6600]
# Out:
# 'سوپر گروه دوست یابی       لینک گروه داخل کانال قرار داره'

# %%
dataset.to_csv('newdata.csv')

# %%
datanew=pd.read_csv('newdata.csv')

# %%
datanew
# Out:
#        Unnamed: 0                                            message  \
# 0               0  تار طرب گسسته شد    پای طلب شکسته شد     راه ا...
# 1               1  نامه رهبرمعظم انقلاب به احمدی نژاد       ادعای...
# 2               2  پر از فیلم سکسی   گیف سکسی   کیرت شق کرده بیا ...
# 3               3  سلام   جمعه مبارک   جمعه تون مثل لبخند زیبا   ...
# 4               4  نرگس ار لاف زد از شیوه چشم تو مرنج   نروند اهل...
# ...           ...                                                ...
# 85736       85736  نوشته شعر فقط بهانه است  من با صدای بلند به شم...
# 85737       85737                          سیستمت اگه  باشه  هم میشه
# 85738       85738  سلام دوتا سوال از سینتیک و طراحی راکتور دارم ک...
# 85739       85739  یه مرکز خیریه هست به اسم موسسه رضوان ادرس موسس...
# 85740       85740  سلام   از همکاران گرامی اگر کسی سرکار خانم نظر...
#
#       sentiment1
# 0       negative
# 1       negative
# 2       negative
# 3       negative
# 4       negative
# ...          ...
# 85736   negative
# 85737   negative
# 85738   positive
# 85739   negative
# 85740   negative
#
# [85741 rows x 3 columns]

# %%
datanew.drop('Unnamed: 0',axis=1,inplace=True)

# %%
datanew
# Out:
#                                                  message sentiment1
# 0      تار طرب گسسته شد    پای طلب شکسته شد     راه ا...   negative
# 1      نامه رهبرمعظم انقلاب به احمدی نژاد       ادعای...   negative
# 2      پر از فیلم سکسی   گیف سکسی   کیرت شق کرده بیا ...   negative
# 3      سلام   جمعه مبارک   جمعه تون مثل لبخند زیبا   ...   negative
# 4      نرگس ار لاف زد از شیوه چشم تو مرنج   نروند اهل...   negative
# ...                                                  ...        ...
# 85736  نوشته شعر فقط بهانه است  من با صدای بلند به شم...   negative
# 85737                          سیستمت اگه  باشه  هم میشه   negative
# 85738  سلام دوتا سوال از سینتیک و طراحی راکتور دارم ک...   positive
# 85739  یه مرکز خیریه هست به اسم موسسه رضوان ادرس موسس...   negative
# 85740  سلام   از همکاران گرامی اگر کسی سرکار خانم نظر...   negative
#
# [85741 rows x 2 columns]

# %%
datanew = datanew.dropna(how='any',axis=0)

# %%
datanew
# Out:
#                                                  message sentiment1
# 0      تار طرب گسسته شد    پای طلب شکسته شد     راه ا...   negative
# 1      نامه رهبرمعظم انقلاب به احمدی نژاد       ادعای...   negative
# 2      پر از فیلم سکسی   گیف سکسی   کیرت شق کرده بیا ...   negative
# 3      سلام   جمعه مبارک   جمعه تون مثل لبخند زیبا   ...   negative
# 4      نرگس ار لاف زد از شیوه چشم تو مرنج   نروند اهل...   negative
# ...                                                  ...        ...
# 85736  نوشته شعر فقط بهانه است  من با صدای بلند به شم...   negative
# 85737                          سیستمت اگه  باشه  هم میشه   negative
# 85738  سلام دوتا سوال از سینتیک و طراحی راکتور دارم ک...   positive
# 85739  یه مرکز خیریه هست به اسم موسسه رضوان ادرس موسس...   negative
# 85740  سلام   از همکاران گرامی اگر کسی سرکار خانم نظر...   negative
#
# [76810 rows x 2 columns]

# %%
datanew.to_csv('newdata.csv')

# %%
dataset=pd.read_csv('newdata.csv')

# %%
dataset
# Out:
#        Unnamed: 0                                            message  \
# 0               0  تار طرب گسسته شد    پای طلب شکسته شد     راه ا...
# 1               1  نامه رهبرمعظم انقلاب به احمدی نژاد       ادعای...
# 2               2  پر از فیلم سکسی   گیف سکسی   کیرت شق کرده بیا ...
# 3               3  سلام   جمعه مبارک   جمعه تون مثل لبخند زیبا   ...
# 4               4  نرگس ار لاف زد از شیوه چشم تو مرنج   نروند اهل...
# ...           ...                                                ...
# 76805       85736  نوشته شعر فقط بهانه است  من با صدای بلند به شم...
# 76806       85737                          سیستمت اگه  باشه  هم میشه
# 76807       85738  سلام دوتا سوال از سینتیک و طراحی راکتور دارم ک...
# 76808       85739  یه مرکز خیریه هست به اسم موسسه رضوان ادرس موسس...
# 76809       85740  سلام   از همکاران گرامی اگر کسی سرکار خانم نظر...
#
#       sentiment1
# 0       negative
# 1       negative
# 2       negative
# 3       negative
# 4       negative
# ...          ...
# 76805   negative
# 76806   negative
# 76807   positive
# 76808   negative
# 76809   negative
#
# [76810 rows x 3 columns]

# %%
dataset.drop('Unnamed: 0',axis=1,inplace=True)

# %%
dataset
# Out:
#                                                  message sentiment1
# 0      تار طرب گسسته شد    پای طلب شکسته شد     راه ا...   negative
# 1      نامه رهبرمعظم انقلاب به احمدی نژاد       ادعای...   negative
# 2      پر از فیلم سکسی   گیف سکسی   کیرت شق کرده بیا ...   negative
# 3      سلام   جمعه مبارک   جمعه تون مثل لبخند زیبا   ...   negative
# 4      نرگس ار لاف زد از شیوه چشم تو مرنج   نروند اهل...   negative
# ...                                                  ...        ...
# 76805  نوشته شعر فقط بهانه است  من با صدای بلند به شم...   negative
# 76806                          سیستمت اگه  باشه  هم میشه   negative
# 76807  سلام دوتا سوال از سینتیک و طراحی راکتور دارم ک...   positive
# 76808  یه مرکز خیریه هست به اسم موسسه رضوان ادرس موسس...   negative
# 76809  سلام   از همکاران گرامی اگر کسی سرکار خانم نظر...   negative
#
# [76810 rows x 2 columns]

# %%
dataset.shape
# Out:
# (76810, 2)

# %%
def remove_ezafe(row):
    row = str(row)
    cleantext = re.sub(r"( را )|( آن )|( اما )|( ها )|(ان )|(ات )|( می )|( که )|( با )|( او )|( در )|( از )|( اگر )|( زیر )|( روی )|( برای )|( یک )|( دو )|( سه )|( چهار )|( پنج )|( شش )|( هفت )|( هشت )|( نه )|( ده )|( و )|(یان )|( های )|( هر )|( مانند )|( این )|( همین )|( به )|( ای )", " ", row)
    return cleantext

# %%
dataset['message']=dataset['message'].apply(remove_ezafe)

# %%
dataset.message[40]
# Out:
# 'مجموع صلو       خدایا تکلیف سنگین طاقت فرسا بر ما نگذار چنانچه بر پیشین ما نهادی'

# %%
dataset
# Out:
#                                                  message sentiment1
# 0      تار طرب گسسته شد    پای طلب شکسته شد     راه ا...   negative
# 1      نامه رهبرمعظم انقلاب احمدی نژاد       ادعای غل...   negative
# 2      پر فیلم سکسی   گیف سکسی   کیرت شق کرده بیا توو...   negative
# 3      سلام   جمعه مبارک   جمعه تون مثل لبخند زیبا   ...   negative
# 4      نرگس ار لاف زد شیوه چشم تو مرنج   نروند اهل نظ...   negative
# ...                                                  ...        ...
# 76805  نوشته شعر فقط بهانه است  من صدای بلند شما فکر ...   negative
# 76806                          سیستمت اگه  باشه  هم میشه   negative
# 76807  سلام دوتا سوال سینتیک طراحی راکتور دارم کسی بلده؟   positive
# 76808  یه مرکز خیریه هست اسم موسسه رضو ادرس موسسه هم ...   negative
# 76809  سلام   همکار گرامی کسی سرکار خانم نظری مدرس تر...   negative
#
# [76810 rows x 2 columns]

# %%
dataset['flag']=[1 if (x=="positive") else 0 for x in dataset['sentiment1']]
dataset
# Out:
#                                                  message sentiment1  flag
# 0      تار طرب گسسته شد    پای طلب شکسته شد     راه ا...   negative     0
# 1      نامه رهبرمعظم انقلاب احمدی نژاد       ادعای غل...   negative     0
# 2      پر فیلم سکسی   گیف سکسی   کیرت شق کرده بیا توو...   negative     0
# 3      سلام   جمعه مبارک   جمعه تون مثل لبخند زیبا   ...   negative     0
# 4      نرگس ار لاف زد شیوه چشم تو مرنج   نروند اهل نظ...   negative     0
# ...                                                  ...        ...   ...
# 76805  نوشته شعر فقط بهانه است  من صدای بلند شما فکر ...   negative     0
# 76806                          سیستمت اگه  باشه  هم میشه   negative     0
# 76807  سلام دوتا سوال سینتیک طراحی راکتور دارم کسی بلده؟   positive     1
# 76808  یه مرکز خیریه هست اسم موسسه رضو ادرس موسسه هم ...   negative     0
# 76809  سلام   همکار گرامی کسی سرکار خانم نظری مدرس تر...   negative     0
#
# [76810 rows x 3 columns]

# %%
dataset.shape
# Out:
# (10001, 3)

# %%
dataset=dataset.loc[20000:30000]

# %%
import pandas
import pandas as pd
training_data = dataset
training_data = pandas.DataFrame(training_data, columns=['message', 'flag'])
print(training_data.message.shape)
# Out:
# (10001,)

# %%
import pickle
from sklearn.feature_extraction.text import CountVectorizer
#GET VECTOR COUNT
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(training_data.message)
#SAVE WORD VECTOR
pickle.dump(count_vect.vocabulary_, open("count_vector.pkl","wb"))

# %%
from sklearn.feature_extraction.text import TfidfTransformer
#TRANSFORM WORD VECTOR TO TF IDF
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
#SAVE TF-IDF
pickle.dump(tfidf_transformer, open("tfidf.pkl","wb"))

# %%
# Multinomial Naive Bayes
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
#clf = MultinomialNB().fit(X_train_tfidf, training_data.flag)
X_train, X_test, y_train, y_test = train_test_split(X_train_tfidf, training_data.flag, test_size=0.15)
clf = MultinomialNB().fit(X_train, y_train)
#SAVE MODEL
pickle.dump(clf, open("nb_model.pkl", "wb"))

# %%
import pickle
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
category_list = ["negative","positive"]
loaded_vec = CountVectorizer(vocabulary=pickle.load(open("count_vector.pkl", "rb")))
loaded_tfidf = pickle.load(open("tfidf.pkl","rb"))
loaded_model = pickle.load(open("nb_model.pkl","rb"))

# %%
predicted = loaded_model.predict(X_test)
result_bayes = pandas.DataFrame( {'true_labels': y_test,'predicted_labels': predicted})
result_bayes.to_csv('res_bayes.csv', sep = ',')

for predicted_item, result in zip(predicted, y_test):
    print(category_list[predicted_item], ' - ', category_list[result])
# Out:
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive

# %%
from sklearn.metrics import recall_score, precision_score, f1_score, accuracy_score
print('Accuracy Score:', accuracy_score(y_test,predicted))
print('Precision Score:', precision_score(y_test, predicted, average='macro'))
print('Recall Score:', recall_score(y_test, predicted, average='macro'))
print('F1 Score:', f1_score(y_test, predicted, average='macro'))
# Out:
# Accuracy Score: 0.8421052631578947
# Precision Score: 0.8467184545218585
# Recall Score: 0.8352400653941576
# F1 Score: 0.8383760779675941

# %%
from sklearn.metrics import recall_score, precision_score, f1_score, accuracy_score
print('Accuracy Score:', accuracy_score(y_test,predicted))
print('Precision Score:', precision_score(y_test, predicted, average='macro'))
print('Recall Score:', recall_score(y_test, predicted, average='macro'))
print('F1 Score:', f1_score(y_test, predicted, average='macro'))
# Out:
# Accuracy Score: 0.8421052631578947
# Precision Score: 0.8467184545218585
# Recall Score: 0.8352400653941576
# F1 Score: 0.8383760779675941

# %%
#import matplotlib.pyplot as plt
#import scikitplot as skplt
#skplt.metrics.plot_confusion_matrix(y_test, predicted,title='naive',normalize=True)
#plt.show()

# %%
from sklearn.neural_network import MLPClassifier
clf_neural = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(25,), random_state=1)
X_train, X_test, y_train, y_test = train_test_split(X_train_tfidf, training_data.flag, test_size=0.1)
clf_neural.fit(X_train, y_train)
pickle.dump(clf_neural, open("softmax.pkl", "wb"))

# %%
import pickle
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
category_list = ["negative","positive"]
loaded_vec = CountVectorizer(vocabulary=pickle.load(open("count_vector.pkl", "rb")))
loaded_tfidf = pickle.load(open("tfidf.pkl","rb"))
loaded_model = pickle.load(open("softmax.pkl","rb"))

# %%
predicted = clf_neural.predict(X_test)
result_softmax = pandas.DataFrame( {'true_labels': y_test,'predicted_labels': predicted})
result_softmax.to_csv('res_softmax.csv', sep = ',')

for predicted_item, result in zip(predicted, y_test):
    print(category_list[predicted_item], ' - ', category_list[result])
# Out:
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# ...
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  negative

# %%
#شبکه عصبی
from sklearn.metrics import recall_score, precision_score, f1_score, accuracy_score
print('Accuracy Score:', accuracy_score(y_test,predicted))
print('Precision Score:', precision_score(y_test, predicted, average='macro'))
print('Recall Score:', recall_score(y_test, predicted, average='macro'))
print('F1 Score:', f1_score(y_test, predicted, average='macro'))
# Out:
# Accuracy Score: 0.8903788569196719
# Precision Score: 0.8903217275974581
# Recall Score: 0.8904234375955895
# F1 Score: 0.8903551262666951

# %%
#import matplotlib.pyplot as plt
#import scikitplot as skplt
#skplt.metrics.plot_confusion_matrix(y_test, predicted,normalize=True)
#plt.show()

# %%
from sklearn import svm
clf_svm = svm.LinearSVC()
X_train, X_test, y_train, y_test = train_test_split(X_train_tfidf, training_data.flag, test_size=0.1)
clf_svm.fit(X_train_tfidf, training_data.flag)
pickle.dump(clf_svm, open("svm.pkl", "wb"))

# %%
import pickle
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
category_list = ["negative","positive"]
loaded_vec = CountVectorizer(vocabulary=pickle.load(open("count_vector.pkl", "rb")))
loaded_tfidf = pickle.load(open("tfidf.pkl","rb"))
loaded_model = pickle.load(open("svm.pkl","rb"))

# %%
predicted = clf_svm.predict(X_test)
result_svm = pandas.DataFrame( {'true_labels': y_test,'predicted_labels': predicted})
result_svm.to_csv('res_svm.csv', sep = ',')
for predicted_item, result in zip(predicted, y_test):
    print(category_list[predicted_item], ' - ', category_list[result])
# Out:
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# ...
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative

# %%
#ماشین بردار پشتیبان
from sklearn.metrics import recall_score, precision_score, f1_score, accuracy_score
print('Accuracy Score:', accuracy_score(y_test,predicted))
print('Precision Score:', precision_score(y_test, predicted, average='macro'))
print('Recall Score:', recall_score(y_test, predicted, average='macro'))
print('F1 Score:', f1_score(y_test, predicted, average='macro'))
# Out:
# Accuracy Score: 0.9601614373128499
# Precision Score: 0.9603742341447259
# Recall Score: 0.9600316259163248
# F1 Score: 0.9601402709935036

# %%
#import matplotlib.pyplot as plt
#import scikitplot as skplt
#skplt.metrics.plot_confusion_matrix(y_test, predicted,normalize=True)
#plt.show()

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(C=1e5,solver='lbfgs',multi_class='multinomial')
X_train, X_test, y_train, y_test = train_test_split(X_train_tfidf, training_data.flag, test_size=0.1)
logreg.fit(X_train, y_train)
pickle.dump(logreg, open("reg.pkl", "wb"))

# %%
import pickle
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
category_list = ["negative","positive"]
loaded_vec = CountVectorizer(vocabulary=pickle.load(open("count_vector.pkl", "rb")))
loaded_tfidf = pickle.load(open("tfidf.pkl","rb"))
loaded_model = pickle.load(open("reg.pkl","rb"))

# %%
predicted = logreg.predict(X_test)
result_logreg = pandas.DataFrame( {'true_labels': y_test,'predicted_labels': predicted})
result_logreg.to_csv('res_logreg.csv', sep = ',')
for predicted_item, result in zip(predicted, y_test):
    print(category_list[predicted_item], ' - ', category_list[result])
# Out:
# positive  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# ...
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  positive
# positive  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive

# %%
from sklearn.metrics import recall_score, precision_score, f1_score, accuracy_score
print('Accuracy Score:', accuracy_score(y_test,predicted))
print('Precision Score:', precision_score(y_test, predicted, average='macro'))
print('Recall Score:', recall_score(y_test, predicted, average='macro'))
print('F1 Score:', f1_score(y_test, predicted, average='macro'))
# Out:
# Accuracy Score: 0.8699388100507747
# Precision Score: 0.870071294147929
# Recall Score: 0.870117823540023
# F1 Score: 0.8699380957854153

# %%
#import matplotlib.pyplot as plt
#import scikitplot as skplt
#skplt.metrics.plot_confusion_matrix(y_test, predicted,normalize=True)
#plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
clff = RandomForestClassifier(n_estimators=200,max_depth=10,random_state=0)
X_train, X_test, y_train, y_test = train_test_split(X_train_tfidf, training_data.flag, test_size=0.10)
clff.fit(X_train, y_train)
pickle.dump(clff, open("clf.pkl", "wb"))

# %%
import pickle
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
category_list = ["negative","positive"]
loaded_vec = CountVectorizer(vocabulary=pickle.load(open("count_vector.pkl", "rb")))
loaded_tfidf = pickle.load(open("tfidf.pkl","rb"))
loaded_model = pickle.load(open("clf.pkl","rb"))

# %%
predicted = clff.predict(X_test)
result_clff = pandas.DataFrame( {'true_labels': y_test,'predicted_labels': predicted})
result_clff.to_csv('res_clff.csv', sep = ',')
for predicted_item, result in zip(predicted, y_test):
    print(category_list[predicted_item], ' - ', category_list[result])
# Out:
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# ...
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  negative
# negative  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive

# %%
#روش جنگل تصادفی
from sklearn.metrics import recall_score, precision_score, f1_score, accuracy_score
print('Accuracy Score:', accuracy_score(y_test,predicted))
print('Precision Score:', precision_score(y_test, predicted, average='macro'))
print('Recall Score:', recall_score(y_test, predicted, average='macro'))
print('F1 Score:', f1_score(y_test, predicted, average='macro'))
# Out:
# Accuracy Score: 0.8427288113526884
# Precision Score: 0.8447880531957286
# Recall Score: 0.8449790652736473
# F1 Score: 0.842727635763794

# %%
#import matplotlib.pyplot as plt
#import scikitplot as skplt
#skplt.metrics.plot_confusion_matrix(y_test, predicted,normalize=True)
#plt.show()

# %%
from sklearn.linear_model import SGDClassifier
sgd = SGDClassifier(n_jobs=-1, n_iter=10, alpha=1e-05, loss='hinge', random_state=1234)
X_train, X_test, y_train, y_test = train_test_split(X_train_tfidf, training_data.flag, test_size=0.10)
sgd.fit(X_train, y_train)
pickle.dump(logreg, open("sgd.pkl", "wb"))
category_list = ["negative","positive"]
loaded_vec = CountVectorizer(vocabulary=pickle.load(open("count_vector.pkl", "rb")))
loaded_tfidf = pickle.load(open("tfidf.pkl","rb"))
loaded_model = pickle.load(open("sgd.pkl","rb"))
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)

# %%
predicted = sgd.predict(X_test)
result_clff = pandas.DataFrame( {'true_labels': y_test,'predicted_labels': predicted})
result_clff.to_csv('sgd.csv', sep = ',')
for predicted_item, result in zip(predicted, y_test):
    print(category_list[predicted_item], ' - ', category_list[result])
# Out:
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# ...
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  negative
# positive  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  positive
# positive  -  negative
# positive  -  positive
# positive  -  positive
# negative  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# positive  -  positive
# positive  -  positive
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  negative
# positive  -  positive
# negative  -  negative
# negative  -  negative
# negative  -  negative
# positive  -  positive
# negative  -  positive
# positive  -  positive

# %%
from sklearn.metrics import recall_score, precision_score, f1_score, accuracy_score
print('Accuracy Score:', accuracy_score(y_test,predicted))
print('Precision Score:', precision_score(y_test, predicted, average='macro'))
print('Recall Score:', recall_score(y_test, predicted, average='macro'))
print('F1 Score:', f1_score(y_test, predicted, average='macro'))
# Out:
# Accuracy Score: 0.8962374690795469
# Precision Score: 0.896111266003366
# Recall Score: 0.8962361462310908
# F1 Score: 0.8961656552253876

# %%
from nltk.util import ngrams

# %%
#ngram_vect=ngrams(training_data.message, 2)
#pickle.dump(ngram_vect.vocabulary_, open("ngram_vect.pkl","wb"))

# %%
from sklearn.feature_extraction.text import TfidfTransformer
#TRANSFORM WORD VECTOR TO TF IDF
#tfidf_transformer = TfidfTransformer()
#X_train_tfidf = tfidf_transformer.fit_transform(ngram_vect)
#SAVE TF-IDF
#pickle.dump(tfidf_transformer, open("tfidff.pkl","wb"))

# %%
text=training_data.message[30]
text
# Out:
# 'در اسفناج مواد معدنی همچنین فولیک اسید وجود دارد  ماده میتواند افسردگی به صورت قابل ملاحظه کاهش دهد   مقدار زیادی زینک هم وجوددارد برای درم افسردگی بسیار موثر میباشد'

# %%
tokens = [token for token in text.split(" ") if token != ""]
output = list(ngrams(tokens, 2))

# %%
output
pickle.dump(ngram_vect.vocabulary_, open("ngram_vect.pkl","wb"))
# Out:
# [('در', 'اسفناج'),
#  ('اسفناج', 'مواد'),
#  ('مواد', 'معدنی'),
#  ('معدنی', 'همچنین'),
#  ('همچنین', 'فولیک'),
#  ('فولیک', 'اسید'),
#  ('اسید', 'وجود'),
#  ('وجود', 'دارد'),
#  ('دارد', 'ماده'),
#  ('ماده', 'میتواند'),
#  ('میتواند', 'افسردگی'),
#  ('افسردگی', 'به'),
#  ('به', 'صورت'),
#  ('صورت', 'قابل'),
#  ('قابل', 'ملاحظه'),
#  ('ملاحظه', 'کاهش'),
#  ('کاهش', 'دهد'),
#  ('دهد', 'مقدار'),
#  ('مقدار', 'زیادی'),
#  ('زیادی', 'زینک'),
#  ('زینک', 'هم'),
#  ('هم', 'وجوددارد'),
#  ('وجوددارد', 'برای'),
#  ('برای', 'درم'),
#  ('درم', 'افسردگی'),
#  ('افسردگی', 'بسیار'),
#  ('بسیار', 'موثر'),
#  ('موثر', 'میباشد')]
